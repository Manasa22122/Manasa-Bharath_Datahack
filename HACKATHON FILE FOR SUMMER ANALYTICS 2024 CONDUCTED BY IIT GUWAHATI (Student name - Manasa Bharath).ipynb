# %%
# Train data

# %%
import pandas as pd
df = pd.read_csv('/content/training_set_features - Copy.csv')
print (df)
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 15842          15842          1.0            2.0                        0.0
# 15843          15843          2.0            1.0                        0.0
# 15844          15844          1.0            1.0                        0.0
# 15845          15845          1.0            1.0                        0.0
# 15846          15846          2.0            2.0                        0.0
#
# ...

# %%
df2 = pd.get_dummies(data=df, columns=[ 'age_group', 'education','race','sex','income_poverty', 'marital_status','rent_or_own','employment_status','census_msa','household_adults','household_children', 'hhs_geo_region','employment_industry','employment_occupation'], dtype='int')
print (df2)
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 15842          15842          1.0            2.0                        0.0
# 15843          15843          2.0            1.0                        0.0
# 15844          15844          1.0            1.0                        0.0
# 15845          15845          1.0            1.0                        0.0
# 15846          15846          2.0            2.0                        0.0
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
print(df2.xyz_vaccine)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15842    1
# 15843    0
# 15844    0
# 15845    0
# 15846    1
# Name: xyz_vaccine, Length: 15847, dtype: int64

# %%
df3 = df2.fillna(-1)
df3
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 15842          15842          1.0            2.0                        0.0
# 15843          15843          2.0            1.0                        0.0
# 15844          15844          1.0            1.0                        0.0
# 15845          15845          1.0            1.0                        0.0
# 15846          15846          2.0            2.0                        0.0
#
# ...

# %%
y_train = df3['xyz_vaccine']
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15842    1
# 15843    0
# 15844    0
# 15845    0
# 15846    1
# Name: xyz_vaccine, Length: 15847, dtype: int64

# %%
x_train = df3.drop('xyz_vaccine', axis=1)
x_train
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0                  0          1.0            0.0                        0.0
# 1                  1          3.0            2.0                        0.0
# 2                  2          1.0            1.0                        0.0
# 3                  3          1.0            1.0                        0.0
# 4                  4          2.0            1.0                        0.0
# ...              ...          ...            ...                        ...
# 15842          15842          1.0            2.0                        0.0
# 15843          15843          2.0            1.0                        0.0
# 15844          15844          1.0            1.0                        0.0
# 15845          15845          1.0            1.0                        0.0
# 15846          15846          2.0            2.0                        0.0
#
# ...

# %%
A = list (df3.columns)
print(A)
# Out:
# ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'xyz_vaccine', 'age_group_18 - 34 Years', 'age_group_35 - 44 Years', 'age_group_45 - 54 Years', 'age_group_55 - 64 Years', 'age_group_65+ Years', 'education_12 Years', 'education_< 12 Years', 'education_College Graduate', 'education_Some College', 'race_Black', 'race_Hispanic', 'race_Other or Multiple', 'race_White', 'sex_Female', 'sex_Male', 'income_poverty_<= $75,000, Above Poverty', 'income_poverty_> $75,000', 'income_poverty_Below Poverty', 'marital_status_Marrie
# ...

# %%
#Test data

# %%
import pandas as pd
df4 = pd.read_csv('/content/test_set_features - Copy.csv')
print (df4)
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
df5 = pd.get_dummies(data=df4, columns=[ 'age_group', 'education','race','sex','income_poverty', 'marital_status','rent_or_own','employment_status','census_msa','household_adults','household_children', 'hhs_geo_region','employment_industry','employment_occupation'], dtype='int')
print (df5)
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
df6 = df5.fillna(-1)
df6
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
B = list (df6.columns)
print(B)
# Out:
# ['respondent_id', 'xyz_concern', 'xyz_knowledge', 'behavioral_antiviral_meds', 'behavioral_avoidance', 'behavioral_face_mask', 'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home', 'behavioral_touch_face', 'doctor_recc_xyz', 'doctor_recc_seasonal', 'chronic_med_condition', 'child_under_6_months', 'health_worker', 'health_insurance', 'opinion_xyz_vacc_effective', 'opinion_xyz_risk', 'opinion_xyz_sick_from_vacc', 'opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'xyz_vaccine', 'age_group_18 - 34 Years', 'age_group_35 - 44 Years', 'age_group_45 - 54 Years', 'age_group_55 - 64 Years', 'age_group_65+ Years', 'education_12 Years', 'education_< 12 Years', 'education_College Graduate', 'education_Some College', 'race_Black', 'race_Hispanic', 'race_Other or Multiple', 'race_White', 'sex_Female', 'sex_Male', 'income_poverty_<= $75,000, Above Poverty', 'income_poverty_> $75,000', 'income_poverty_Below Poverty', 'marital_status_Marrie
# ...

# %%
A.sort()
B.sort()

if A == B:
    print ("The lists A and B are the same")
else:
    print ("The lists A and B are not the same")
# Out:
# The lists A and B are the same

# %%
y_test= df6['xyz_vaccine']
y_test
# Out:
# 0       -1.0
# 1       -1.0
# 2       -1.0
# 3       -1.0
# 4       -1.0
#         ...
# 26703   -1.0
# 26704   -1.0
# 26705   -1.0
# 26706   -1.0
# 26707   -1.0
# Name: xyz_vaccine, Length: 26708, dtype: float64

# %%
x_test = df6.drop('xyz_vaccine', axis=1)
x_test
# Out:
#        respondent_id  xyz_concern  xyz_knowledge  behavioral_antiviral_meds  \
# 0              26707          2.0            2.0                        0.0
# 1              26708          1.0            1.0                        0.0
# 2              26709          2.0            2.0                        0.0
# 3              26710          1.0            1.0                        0.0
# 4              26711          3.0            1.0                        1.0
# ...              ...          ...            ...                        ...
# 26703          53410          1.0            1.0                        0.0
# 26704          53411          3.0            1.0                        0.0
# 26705          53412          0.0            1.0                        0.0
# 26706          53413          3.0            1.0                        0.0
# 26707          53414          2.0            1.0                        0.0
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=5, random_state=200)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=200)

# %%
y_rf_train_pred = rf.predict (x_train)
y_rf_test_pred = rf.predict(x_test)
y_rf_test_pred
# Out:
# array([0.20575235, 0.03488691, 0.1570322 , ..., 0.11677803, 0.03229865,
#        0.75818635])

# %%
numpy_array = y_rf_test_pred
list_from_numpy = numpy_array.tolist()
print(list_from_numpy)
# Out:
# [0.20575235137841044, 0.034886914429729965, 0.15703219782669117, 0.5724706686604825, 0.38325685156610395, 0.6983018135013307, 0.27075499711459494, 0.20805566582253743, 0.03229864929072048, 0.1067562070142308, 0.03229864929072048, 0.3564576574878143, 0.11554994774046351, 0.03229864929072048, 0.47511414313122197, 0.09991708692815832, 0.8034499339588167, 0.03229864929072048, 0.03229864929072048, 0.03643750524610098, 0.35672872933335564, 0.30616904267444517, 0.032010655314214036, 0.03229864929072048, 0.0846619073880412, 0.3028756782159287, 0.8522172890433372, 0.8430569306847251, 0.03229864929072048, 0.09991708692815832, 0.08944354533926412, 0.7393262823378808, 0.09991708692815832, 0.34680741299663054, 0.09076113467181543, 0.09991708692815832, 0.09513544897693543, 0.03229864929072048, 0.07836467449979687, 0.14060675876963127, 0.03229864929072048, 0.07720311421164175, 0.09991708692815832, 0.3825782127825819, 0.6854161774793652, 0.08944354533926412, 0.30387550288090537, 0.11554994774046351,
# ...

# %%
C['xyz_vaccine'] = pd.Series(list_from_numpy)
C
# Out:
#        respondent_id  xyz_vaccine
# 0                  0     0.205752
# 1                  1     0.034887
# 2                  2     0.157032
# 3                  3     0.572471
# 4                  4     0.383257
# ...              ...          ...
# 15842          15842     0.032299
# 15843          15843     0.510914
# 15844          15844     0.597499
# 15845          15845     0.085879
# 15846          15846     0.852972
#
# [15847 rows x 2 columns]

# %%
C.to_csv('file1.csv')
